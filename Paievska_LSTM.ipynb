# %% [markdown]
# ## Лабораторна робота 2.1.1

# %% [markdown]
# Завдання: Створити RNN для семантичного аналізу тексту з використанням:  модел LSTM. .
# Розробити власну архітектуру, кількість рекурентних шарів, функції
# активації, вибрати оптиміза ор.
# Отримати для двох моделей по дві рецензії (позитивну і негативну).

# %%
#Імпортуємо всі необхідні біблідтеки
import numpy as np
import re

from tensorflow.keras.layers import Dense, LSTM, Input, Dropout, Embedding
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.text import Tokenizer, text_to_word_sequence
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
#Задаємо тексти 

#Позитивний текст
texts_true = [
    "I really like this song!",
    "It is the best place I have ever seen.",
    "Honey, you are so beautiful girl.",
]

#Негативний текст
texts_false = [
    "This is a terrible song! Please turn it off.",
    "I am disappointed with this place. It used to be better here.",
    "What a horror! You are a monster.",
]

# %%
# Об'єднання текстів
texts = texts_true + texts_false
count_true = len(texts_true)
count_false = len(texts_false)
total_lines = count_true + count_false
print(count_true, count_false, total_lines)

#Токенізація
maxWordsCount = 1000
tokenizer = Tokenizer(num_words=maxWordsCount, filters='!–"—#$%&amp;()*+,-./:;<=>?@[\\]^_`{|}~\t\n\r«»', lower=True, split=' ', char_level=False)
tokenizer.fit_on_texts(texts)

#Робота з текстом
dist = list(tokenizer.word_counts.items())
print(dist[:10])
print(texts[0][:100])

max_text_len = 10
data = tokenizer.texts_to_sequences(texts)
data_pad = pad_sequences(data, maxlen=max_text_len)
print(data_pad)

print(list(tokenizer.word_index.items()))

X = data_pad
Y = np.array([[1, 0]]*count_true + [[0, 1]]*count_false)
print(X.shape, Y.shape)

indices = np.random.choice(X.shape[0], size=X.shape[0], replace=False)
X = X[indices]
Y = Y[indices]

#Створення моделі та навчання моделі

model = Sequential()
model.add(Embedding(maxWordsCount, 64, input_length=max_text_len))
model.add(LSTM(50))
model.add(Dense(2, activation='softmax'))
model.summary()

model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer=Adam(0.0001))

history = model.fit(X, Y, batch_size=64, epochs=120)

#Функція для перетворення послідовності чисел у текст

reverse_word_map = dict(map(reversed, tokenizer.word_index.items()))

def sequence_to_text(list_of_indices):
    words = [reverse_word_map.get(letter) for letter in list_of_indices]
    return(words)
# Out:
# 3 3 6
# [('i', 3), ('re', 3), ('lly', 1), ('like', 1), ('this', 3), ('song', 2), ('it', 3), ('is', 2), ('the', 1), ('best', 1)]
# I really like this song!
# [[ 0  0  0  0  1  2 11 12  3  5]
#  [ 6 13 14  7  8  1 15 16 17 18]
#  [ 0  0  0 19  9  2 20 10 21 22]
#  [ 0  3  6 23  5 24 25 26  4 27]
#  [30  3  7  8  4 31 32 10 33 34]
#  [ 0  0  0  0 35 36 37  9  2 38]]
# [('i', 1), ('re', 2), ('this', 3), ('it', 4), ('song', 5), ('is', 6), ('l', 7), ('ce', 8), ('you', 9), ('be', 10), ('lly', 11), ('like', 12), ('the', 13), ('best', 14), ('h', 15), ('ve', 16), ('ever', 17), ('seen', 18), ('honey', 19), ('so', 20), ('utiful', 21), ('girl', 22), ('terrible', 23), ('le', 24), ('se', 25), ('turn', 26), ('off', 27), ('dis', 28), ('ointed', 29), ('with', 30), ('used', 31), ('to', 32), ('better', 33), ('here', 34), ('wh', 35), ('t', 36), ('horror', 37), ('onster', 38)]
# (6, 10) (6, 2)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 10, 64)            64000
#
#  lstm (LSTM)                 (None, 50)                23000
#
#  dense (Dense)               (None, 2)                 102
#
# =================================================================
# Total params: 87,102
# Trainable params: 87,102
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/120
# 1/1 [==============================] - 2s 2s/step - loss: 0.6940 - accuracy: 0.5000
# Epoch 2/120
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6934 - accuracy: 0.5000
# Epoch 3/120
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6929 - accuracy: 0.5000
# Epoch 4/120
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6923 - accuracy: 0.5000
# Epoch 5/120
# 1/1 [==============================] - 0s 0s/step - loss: 0.6918 - accuracy: 0.5000
# Epoch 6/120
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6912 - accuracy: 0.5000
# Epoch 7/120
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6907 - accuracy: 0.5000
# Epoch 8/120
# 1/1 [==============================] - 0s 0s/step - loss: 0.6901 - accuracy: 0.5000
# Epoch 9/120
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6895 - accuracy: 0.8333
# Epoch 10/120
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6890 - accuracy: 0.8333
# Epoch 11/120
# 1/1 [==============================] - 0s 0s/step - loss: 0.6884 - accuracy: 0.8333
# Epoch 12/120
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6879 - accuracy: 0.8333
# Epoch 13/120
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6873 - accuracy: 0.8333
# Epoch 14/120
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6867 - accuracy: 0.8333
# Epoch 15/120
# 1/1 [==============================] - 0s 0s/step - loss: 0.6862 - accuracy: 0.8333
# Epoch 16/120
# 1/1 [==============================] - 0s 5ms/step - loss: 0.6856 - accuracy: 0.8333
# Epoch 17/120
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6850 - accuracy: 0.8333
# Epoch 18/120
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6844 - accuracy: 0.8333
# Epoch 19/120
# 1/1 [==============================] - 0s 17ms/step - loss: 0.6839 - accuracy: 0.8333
# Epoch 20/120
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6833 - accuracy: 1.0000
# Epoch 21/120
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6827 - accuracy: 1.0000
# Epoch 22/120
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6821 - accuracy: 1.0000
# Epoch 23/120
# 1/1 [==============================] - 0s 21ms/step - loss: 0.6815 - accuracy: 1.0000
# Epoch 24/120
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6809 - accuracy: 1.0000
# Epoch 25/120
# 1/1 [==============================] - 0s 21ms/step - loss: 0.6803 - accuracy: 1.0000
# Epoch 26/120
# 1/1 [==============================] - 0s 21ms/step - loss: 0.6797 - accuracy: 1.0000
# Epoch 27/120
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6790 - accuracy: 1.0000
# Epoch 28/120
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6784 - accuracy: 1.0000
# Epoch 29/120
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6778 - accuracy: 1.0000
# Epoch 30/120
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6771 - accuracy: 1.0000
# Epoch 31/120
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6765 - accuracy: 1.0000
# Epoch 32/120
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6758 - accuracy: 1.0000
# Epoch 33/120
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6751 - accuracy: 1.0000
# Epoch 34/120
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6744 - accuracy: 1.0000
# Epoch 35/120
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6738 - accuracy: 1.0000
# Epoch 36/120
# 1/1 [==============================] - 0s 0s/step - loss: 0.6731 - accuracy: 1.0000
# Epoch 37/120
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6724 - accuracy: 1.0000
# Epoch 38/120
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6716 - accuracy: 1.0000
# Epoch 39/120
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6709 - accuracy: 1.0000
# Epoch 40/120
# 1/1 [==============================] - 0s 7ms/step - loss: 0.6702 - accuracy: 1.0000
# Epoch 41/120
# 1/1 [==============================] - 0s 221us/step - loss: 0.6694 - accuracy: 1.0000
# Epoch 42/120
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6687 - accuracy: 1.0000
# Epoch 43/120
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6679 - accuracy: 1.0000
# Epoch 44/120
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6671 - accuracy: 1.0000
# Epoch 45/120
# 1/1 [==============================] - 0s 7ms/step - loss: 0.6663 - accuracy: 1.0000
# Epoch 46/120
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6655 - accuracy: 1.0000
# Epoch 47/120
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6647 - accuracy: 1.0000
# Epoch 48/120
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6638 - accuracy: 1.0000
# Epoch 49/120
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6630 - accuracy: 1.0000
# Epoch 50/120
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6621 - accuracy: 1.0000
# Epoch 51/120
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6612 - accuracy: 1.0000
# Epoch 52/120
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6604 - accuracy: 1.0000
# Epoch 53/120
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6594 - accuracy: 1.0000
# Epoch 54/120
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6585 - accuracy: 1.0000
# Epoch 55/120
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6576 - accuracy: 1.0000
# Epoch 56/120
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6566 - accuracy: 1.0000
# Epoch 57/120
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6556 - accuracy: 1.0000
# Epoch 58/120
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6547 - accuracy: 1.0000
# Epoch 59/120
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6537 - accuracy: 1.0000
# Epoch 60/120
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6526 - accuracy: 1.0000
# Epoch 61/120
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6516 - accuracy: 1.0000
# Epoch 62/120
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6505 - accuracy: 1.0000
# Epoch 63/120
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6494 - accuracy: 1.0000
# Epoch 64/120
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6483 - accuracy: 1.0000
# Epoch 65/120
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6472 - accuracy: 1.0000
# Epoch 66/120
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6461 - accuracy: 1.0000
# Epoch 67/120
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6449 - accuracy: 1.0000
# Epoch 68/120
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6437 - accuracy: 1.0000
# Epoch 69/120
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6425 - accuracy: 1.0000
# Epoch 70/120
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6413 - accuracy: 1.0000
# Epoch 71/120
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6400 - accuracy: 1.0000
# Epoch 72/120
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6388 - accuracy: 1.0000
# Epoch 73/120
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6375 - accuracy: 1.0000
# Epoch 74/120
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6362 - accuracy: 1.0000
# Epoch 75/120
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6348 - accuracy: 1.0000
# Epoch 76/120
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6334 - accuracy: 1.0000
# Epoch 77/120
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6320 - accuracy: 1.0000
# Epoch 78/120
# 1/1 [==============================] - 0s 6ms/step - loss: 0.6306 - accuracy: 1.0000
# Epoch 79/120
# 1/1 [==============================] - 0s 19ms/step - loss: 0.6292 - accuracy: 1.0000
# Epoch 80/120
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6277 - accuracy: 1.0000
# Epoch 81/120
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6262 - accuracy: 1.0000
# Epoch 82/120
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6247 - accuracy: 1.0000
# Epoch 83/120
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6231 - accuracy: 1.0000
# Epoch 84/120
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6215 - accuracy: 1.0000
# Epoch 85/120
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6199 - accuracy: 1.0000
# Epoch 86/120
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6183 - accuracy: 1.0000
# Epoch 87/120
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6166 - accuracy: 1.0000
# Epoch 88/120
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6149 - accuracy: 1.0000
# Epoch 89/120
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6131 - accuracy: 1.0000
# Epoch 90/120
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6114 - accuracy: 1.0000
# Epoch 91/120
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6096 - accuracy: 1.0000
# Epoch 92/120
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6077 - accuracy: 1.0000
# Epoch 93/120
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6058 - accuracy: 1.0000
# Epoch 94/120
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6039 - accuracy: 1.0000
# Epoch 95/120
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6020 - accuracy: 1.0000
# Epoch 96/120
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6000 - accuracy: 1.0000
# Epoch 97/120
# 1/1 [==============================] - 0s 12ms/step - loss: 0.5980 - accuracy: 1.0000
# Epoch 98/120
# 1/1 [==============================] - 0s 10ms/step - loss: 0.5959 - accuracy: 1.0000
# Epoch 99/120
# 1/1 [==============================] - 0s 8ms/step - loss: 0.5938 - accuracy: 1.0000
# Epoch 100/120
# 1/1 [==============================] - 0s 15ms/step - loss: 0.5917 - accuracy: 1.0000
# Epoch 101/120
# 1/1 [==============================] - 0s 14ms/step - loss: 0.5895 - accuracy: 1.0000
# Epoch 102/120
# 1/1 [==============================] - 0s 8ms/step - loss: 0.5873 - accuracy: 1.0000
# Epoch 103/120
# 1/1 [==============================] - 0s 16ms/step - loss: 0.5851 - accuracy: 1.0000
# Epoch 104/120
# 1/1 [==============================] - 0s 14ms/step - loss: 0.5828 - accuracy: 1.0000
# Epoch 105/120
# 1/1 [==============================] - 0s 6ms/step - loss: 0.5805 - accuracy: 1.0000
# Epoch 106/120
# 1/1 [==============================] - 0s 13ms/step - loss: 0.5781 - accuracy: 1.0000
# Epoch 107/120
# 1/1 [==============================] - 0s 0s/step - loss: 0.5757 - accuracy: 1.0000
# Epoch 108/120
# 1/1 [==============================] - 0s 17ms/step - loss: 0.5732 - accuracy: 1.0000
# Epoch 109/120
# 1/1 [==============================] - 0s 15ms/step - loss: 0.5707 - accuracy: 1.0000
# Epoch 110/120
# 1/1 [==============================] - 0s 16ms/step - loss: 0.5681 - accuracy: 1.0000
# Epoch 111/120
# 1/1 [==============================] - 0s 16ms/step - loss: 0.5655 - accuracy: 1.0000
# Epoch 112/120
# 1/1 [==============================] - 0s 0s/step - loss: 0.5629 - accuracy: 1.0000
# Epoch 113/120
# 1/1 [==============================] - 0s 16ms/step - loss: 0.5602 - accuracy: 1.0000
# Epoch 114/120
# 1/1 [==============================] - 0s 16ms/step - loss: 0.5574 - accuracy: 1.0000
# Epoch 115/120
# 1/1 [==============================] - 0s 11ms/step - loss: 0.5547 - accuracy: 1.0000
# Epoch 116/120
# 1/1 [==============================] - 0s 32ms/step - loss: 0.5518 - accuracy: 1.0000
# Epoch 117/120
# 1/1 [==============================] - 0s 17ms/step - loss: 0.5489 - accuracy: 1.0000
# Epoch 118/120
# 1/1 [==============================] - 0s 7ms/step - loss: 0.5460 - accuracy: 1.0000
# Epoch 119/120
# 1/1 [==============================] - 0s 28ms/step - loss: 0.5430 - accuracy: 1.0000
# Epoch 120/120
# 1/1 [==============================] - 0s 28ms/step - loss: 0.5399 - accuracy: 1.0000

# %%
#Перевірка позитивного тексту
text1 = "I like your sense of humor.".lower()
data = tokenizer.texts_to_sequences([text1])
data_pad = pad_sequences(data, maxlen=max_text_len)
print(sequence_to_text(data[0]))

res = model.predict(data_pad)
print(res, np.argmax(res), sep='\n')

if np.argmax(res) == 0:
    print("Результат. Текст позитивний.")
else:
    print("Результат. Текст негативний.")
# Out:
# ['i', 'like']
# 1/1 [==============================] - 0s 460ms/step
# [[0.5886742  0.41132584]]
# 0
# Результат. Текст позитивний.

# %%
#Перевірка негативного тексту

text2 = "Max is upset because of Clara.".lower()
data1 = tokenizer.texts_to_sequences([text2])
data1_pad = pad_sequences(data1, maxlen=max_text_len)
print( sequence_to_text(data1[0]) )

res1 = model.predict(data1_pad)
print(res1, np.argmax(res1), sep='\n')


if np.argmax(res1) == 1:
    print("Результат. Текст позитивний.")
else:
    print("Результат. Текст негативний.")
# Out:
# ['is']
# 1/1 [==============================] - 0s 32ms/step
# [[0.5524992  0.44750082]]
# 0
# Результат. Текст негативний.

# %% [markdown]
# #### Висновок:
# На практичній роботі я навчилася створити RNN для семантичного аналізу тексту з використанням
# моде LSTM. Також в ході роботи ця модель була навчана до максимально високої точності.MU
